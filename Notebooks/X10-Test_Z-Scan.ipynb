# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
dm15 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-15mmZ.fits')
m15 = dm15[0]

dm12 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-12mmZ.fits')
m12 = dm12[0]

dm9 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-9mmZ.fits')
m9 = dm9[0]

dm7 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-7mmZ.fits')
m7 = dm7[0]

dm5 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-5mmZ.fits')
m5 = dm5[0]

dm3 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-3mmZ.fits')
m3 = dm3[0]

dm2 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-2mmZ.fits')
m2 = dm2[0]

dm1 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-1mmZ.fits')
m1 = dm1[0]

dm0p5 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_-0p5mmZ.fits')
m0p5 = dm0p5[0]

dm0 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_0mmZ.fits')
m0 = dm0[0]

dp0p5 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+0p5mmZ.fits')
p0p5 = dp0p5[0]

dp1 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+1mmZ.fits')
p1 = dp1[0]

dp2 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+2mmZ.fits')
p2 = dp2[0]

dp3 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+3mmZ.fits')
p3 = dp3[0]

dp5 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+5mmZ.fits')
p5 = dp5[0]

dp7 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+7mmZ.fits')
p7 = dp7[0]

dp9 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+9mmZ.fits')
p9 = dp9[0]

dp12 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+12mmZ.fits')
p12 = dp12[0]

dp15 = fits.open('/Volumes/FOXSI-R_B/FOXSI-3_2018Mar/March20/X10Test/FOXSI3_X10-Test_CCD_T2Sx6_10kV_0p02mA_+15mmZ.fits')
p15 = dp15[0]

# %%
fig = plt.figure(figsize=(20,32))
plt.suptitle('X10 temp housing - New 10 Shell FOXSI module - PSF CCD 20180320', fontsize='38',y=0.9)

plt.subplot(5,4,1)
plt.title('Z = -15.0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m15.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,2)
plt.title('Z = -12.0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m12.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])


plt.subplot(5,4,3)
plt.title('Z = -9.0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m9.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])


plt.subplot(5,4,4)
plt.title('Z = -7.0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m7.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,5)
plt.title('Z = -5.0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m5.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,6)
plt.title('Z = -3.0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m3.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,7)
plt.title('Z = -2.0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m2.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,8)
plt.title('Z = -1.0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m1.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,9)
plt.title('Z = -0.5mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m0p5.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,10)
plt.title('Z = 0mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(m0.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,11)
plt.title('Z = +0.5mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p0p5.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,12)
plt.title('Z = +1mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p1.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,13)
plt.title('Z = +2mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p2.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,14)
plt.title('Z = +3mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p3.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,15)
plt.title('Z = +5mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p5.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,16)
plt.title('Z = +7mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p7.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,17)
plt.title('Z = +9mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p9.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,18)
plt.title('Z = +12mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p12.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

plt.subplot(5,4,19)
plt.title('Z = +15mm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
#plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p15.data[0,164:264,454:554], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[-1.8,1.8,-1.8,1.8])

# %%
300 -> 6.5

# %%
100*6.5/300
# Out:
# 2.1666666666666665
