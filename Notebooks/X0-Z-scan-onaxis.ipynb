# %% [markdown]
# # X-scan measured
# #### Stray ligth Facility at the NASA MSFC
# #### CCD Camera
# #### Calibration of July, 2017

# %%
dn80 = fits.open('/Users/Kamilobu/Desktop/X0-Z-scan-fits/FOXSI-X0-zscan_n80.fits')
n80 = dn80[0]

# %%
fig = plt.figure(figsize=(20,45))
plt.suptitle('X0 - Old 10 Shell FOXSI module - PSF CCD 20170727', fontsize='40',y=0.9)

plt.subplot(5,3,1)
plt.title('Z = -8.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(n80.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,2)
plt.title('Z = -6.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(n60.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,3)
plt.title('Z = -4.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(n40.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,4)
plt.title('Z = -2.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(n20.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,5)
plt.title('Z = -1.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(n10.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,6)
plt.title('Z = -0.5cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(n05.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,7)
plt.title('Z = -0.2cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(n02.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,8)
plt.title('Z = 0.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(o00.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,9)
plt.title('Z = +0.2cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p02.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,10)
plt.title('Z = +0.5cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p05.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,11)
plt.title('Z = +1.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p05.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,12)
plt.title('Z = +2.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p20.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,13)
plt.title('Z = +4.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p40.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.subplot(5,3,14)
plt.title('Z = +6.0cm',fontsize=34)
plt.xlabel('arcmin',fontsize=18)
plt.ylabel('arcmin',fontsize=18)
plt.yticks(fontsize=12)
plt.xticks(fontsize=12)
plt.imshow(p60.data[0,160:460,510:810], origin='lower',cmap='viridis',
           norm=matplotlib.colors.LogNorm(),extent=[0,6.5,0,6.5])

plt.savefig('X0-Z-scan-Color-log.png')
